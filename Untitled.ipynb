# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

# %%
df = pd.read_csv('http://logopt.com/data/iris.data', names=['sepal length','sepal width','petal length','petal width', 'class'])

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.plot()

# %%
df.hist(alpha=0.5, bins=30); #

# %%
ddf =pd.read_csv("http://logopt.com/data/SATGPA.csv")

# %%
ddf.head()
# Out:
#    Unnamed: 0  MathSAT  VerbalSAT   GPA
# 0           1      580        420  2.90
# 1           2      670        530  2.83
# 2           3      680        540  2.90
# 3           4      630        640  3.30
# 4           5      620        630  3.61

# %%
ddf["GPA"].hist(alpha=0.2, bins=2);

# %%
df.plot.scatter(x='sepal length', y= 'petal length');

# %%
pokemon = pd.read_csv("http://logopt.com/data/poke.csv",encoding="utf-8",index_col=0)
pokemon
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary                  Japanese
# #
# 1         65       65     45           1      False                     フシギダネ
# 2         80       80     60           1      False                     フシギソウ
# 3        100      100     80           1      False                     フシギバナ
# 3        122      120     80           1      False                フシギバナ・メガ進化
# 4         60       50     65           1      False                      ヒトカゲ
# ..       ...      ...    ...         ...        ...                       ...
# 719      100      150     50           6       True                    ディアンシー
# 719      160      110    110           6       True               ディアンシー・メガ進化
# 720      150      130     70           6       True  フーパ(HoopaHoopa Confined)
# 720      170      130     80           6       True   フーパ(HoopaHoopa Unbound)
# 721      130       90     70           6       True                    ボルケニオン
#
# [800 rows x 13 columns]

# %%
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('http://logopt.com/data/iris.data', names=['sepal length','sepal width','petal length','petal width', 'class'])
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
