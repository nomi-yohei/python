# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df =pd.read_csv("http://logopt.com/data/iris.data",names=['sepal length','sepal width','petal length','petal width', 'class'])

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.hist(alpha=0.5, bins=20);

# %%
df.hist(alpha=0.5, bins=30);

# %%
df.hist(alpha=0.5, bins=15);

# %%
dd =pd.read_csv("http://logopt.com/data/SATGPA.csv")

# %%
dd.head()
# Out:
#    Unnamed: 0  MathSAT  VerbalSAT   GPA
# 0           1      580        420  2.90
# 1           2      670        530  2.83
# 2           3      680        540  2.90
# 3           4      630        640  3.30
# 4           5      620        630  3.61

# %%
dd.hist(alpha=1, bins=40);

# %%
pokemon = pd.read_csv("http://logopt.com/data/poke.csv",encoding="utf-8",index_col=0)
# pokemon["name"]

# %%
pokemon.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Japanese'],
#       dtype='object')

# %%
pokemon.head()['Sp. Atk']
# Out:
# #
# 1     65
# 2     80
# 3    100
# 3    122
# 4     60
# Name: Sp. Atk, dtype: int64

# %%
pokemon['Sp. Atk'].hist(alpha=1, bins=30);

# %%
pokemon['Sp. Def'].hist(alpha=1, bins=30);

# %%
df.plot.scatter(x='sepal length', y= 'petal length');

# %%
pokemon.plot.scatter(x='Sp. Atk', y= 'Sp. Def');

# %%
As =pd.read_csv("http://logopt.com/data/Diamond.csv")

# %%
As.plot.scatter(x="carat",y="price")

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.jointplot( x='sepal length', y='petal length', data=df,  kind='scatter');

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, row='smoker', col='sex', hue='time');

# %%
titanic = sns.load_dataset('titanic')

titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]
