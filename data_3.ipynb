# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/'

# %%
dframe =pd.read_csv("winequality-red.csv",sep=";")

# %%
dframe.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
dframe.alcohol.mean()
# Out:
# 10.422983114446502

# %%
def max_to_mean(arr):
    return arr.max() - arr.min()

# %%
wino=dframe.groupby("quality")

# %%
wino

# %%
wino.describe()
# Out:
#         fixed acidity                                                     \
#                 count      mean       std  min   25%   50%     75%   max
# quality
# 3                10.0  8.360000  1.770875  6.7  7.15  7.50   9.875  11.6
# 4                53.0  7.779245  1.626624  4.6  6.80  7.50   8.400  12.5
# 5               681.0  8.167254  1.563988  5.0  7.10  7.80   8.900  15.9
# 6               638.0  8.347179  1.797849  4.7  7.00  7.90   9.400  14.3
# 7               199.0  8.872362  1.992483  4.9  7.40  8.80  10.100  15.6
# 8                18.0  8.566667  2.119656  5.0  7.25  8.25  10.225  12.6
#
#         volatile acidity            ... sulphates       alcohol             \
#                    count      mean  ...       75%   max   count       mean
# quality                             ...
# 3                   10.0  0.884500  ...     0.615  0.86    10.0   9.955000
# 4                   53.0  0.693962  ...     0.600  2.00    53.0  10.265094
# ...

# %%
max_to_mean(dframe.pH)
# Out:
# 1.2699999999999996

# %%
wino.agg(max_to_mean)# aggは関数などを持ってくるもの
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                  4.9             1.140         0.66             4.5
# 4                  7.9             0.900         1.00            11.6
# 5                 10.9             1.150         0.79            14.3
# 6                  9.6             0.880         0.78            14.5
# 7                 10.7             0.795         0.76             7.7
# 8                  7.6             0.590         0.69             5.0
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 3            0.206                 31.0                  40.0  0.00609  0.47
# 4            0.565                 38.0                 112.0  0.00760  1.16
# 5            0.572                 65.0                 149.0  0.01059  0.86
# 6            0.381                 71.0                 159.0  0.01362  1.15
# ...

# %%
wino.loc["pH"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-3e770fe75e01> in <module>
# ----> 1 wino.loc["pH"]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     578             return self[attr]
#     579
# --> 580         raise AttributeError(
#     581             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     582         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'loc'

# %%
wino.iloc[1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-33ab4a157f69> in <module>
# ----> 1 wino.iloc[1]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     578             return self[attr]
#     579
# --> 580         raise AttributeError(
#     581             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     582         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'iloc'

# %%
type(dframe)
# Out:
# pandas.core.frame.DataFrame

# %%
type(wino)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
dframe.pH.mean()
# Out:
# 3.311113195747343

# %%
wino.pH.describe()
# Out:
#          count      mean       std   min     25%   50%    75%   max
# quality
# 3         10.0  3.398000  0.144052  3.16  3.3125  3.39  3.495  3.63
# 4         53.0  3.381509  0.181441  2.74  3.3000  3.37  3.500  3.90
# 5        681.0  3.304949  0.150618  2.88  3.2000  3.30  3.400  3.74
# 6        638.0  3.318072  0.153995  2.86  3.2200  3.32  3.410  4.01
# 7        199.0  3.290754  0.150101  2.92  3.2000  3.28  3.380  3.78
# 8         18.0  3.267222  0.200640  2.88  3.1625  3.23  3.350  3.72

# %%
wino.agg("mean")
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
wino.agg("max")
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                 11.6             1.580         0.66             5.7
# 4                 12.5             1.130         1.00            12.9
# 5                 15.9             1.330         0.79            15.5
# 6                 14.3             1.040         0.78            15.4
# 7                 15.6             0.915         0.76             8.9
# 8                 12.6             0.850         0.72             6.4
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 3            0.267                 34.0                  49.0  1.00080  3.63
# 4            0.610                 41.0                 119.0  1.00100  3.90
# 5            0.611                 68.0                 155.0  1.00315  3.74
# 6            0.415                 72.0                 165.0  1.00369  4.01
# ...

# %%
dframe["quality/alc"] =dframe["quality"]/ dframe["alcohol"]

# %%
dframe
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dframe.pivot_table(index=["quality"])
# Out:
#            alcohol  chlorides  citric acid   density  fixed acidity  \
# quality
# 3         9.955000   0.122500     0.171000  0.997464       8.360000
# 4        10.265094   0.090679     0.174151  0.996542       7.779245
# 5         9.899706   0.092736     0.243686  0.997104       8.167254
# 6        10.629519   0.084956     0.273824  0.996615       8.347179
# 7        11.465913   0.076588     0.375176  0.996104       8.872362
# 8        12.094444   0.068444     0.391111  0.995212       8.566667
#
#          free sulfur dioxide        pH  quality/alc  residual sugar  \
# quality
# 3                  11.000000  3.398000     0.303286        2.635000
# 4                  12.264151  3.381509     0.392724        2.694340
# 5                  16.983847  3.304949     0.507573        2.528855
# 6                  15.711599  3.318072     0.569801        2.477194
# 7                  14.045226  3.290754     0.614855        2.720603
# ...

# %%
# dframe.pivot_table(index=["quality"]) ##　同一な意味となっている
# wino=dframe.groupby("quality")

# %%
# %matplotlib inline

# %%
dframe.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8736198e50>,
# ...
#       dtype=object)

# %%
dframe.plot(kind="scatter",x="quality",y="alcohol")

# %%
dframe =pd.read_csv("winequality-red.csv",sep=";")

# %%
def read(csv):
    return pd.read_csv(csv)

# %%
dframe1 =read("winequality-red.csv")

# %%
dframe
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
def rank(df):
    df['alc_content_rank'] = np.arange(len(df)) + 1
    return df

# %%
dframe.sort_values("alcohol",ascending=False,inplace=True)

# %%
type(dframe)
# Out:
# pandas.core.frame.DataFrame

# %%
dframe
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 652            15.9              0.36         0.65             7.5      0.096
# 588             5.0              0.42         0.24             2.0      0.060
# 142             5.2              0.34         0.00             1.8      0.050
# 144             5.2              0.34         0.00             1.8      0.050
# 1270            5.0              0.38         0.01             1.6      0.048
# ...             ...               ...          ...             ...        ...
# 371             7.9              0.24         0.40             1.6      0.056
# 528             8.2              0.42         0.49             2.6      0.084
# 1436           10.0              0.38         0.38             1.6      0.169
# 544            14.3              0.31         0.74             1.8      0.075
# 517            10.4              0.61         0.49             2.1      0.200
#
# ...

# %%
dframe12 =dframe.groupby("quality").apply(rank)

# %%
dframe12
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 652            15.9              0.36         0.65             7.5      0.096
# 588             5.0              0.42         0.24             2.0      0.060
# 142             5.2              0.34         0.00             1.8      0.050
# 144             5.2              0.34         0.00             1.8      0.050
# 1270            5.0              0.38         0.01             1.6      0.048
# ...             ...               ...          ...             ...        ...
# 371             7.9              0.24         0.40             1.6      0.056
# 528             8.2              0.42         0.49             2.6      0.084
# 1436           10.0              0.38         0.38             1.6      0.169
# 544            14.3              0.31         0.74             1.8      0.075
# 517            10.4              0.61         0.49             2.1      0.200
#
# ...

# %%
num_of_qual = dframe['quality'].value_counts()#個数が何個あるかわかる

# %%
num_of_qual
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
dframe12[dframe12.alc_content_rank==1].sort_values("quality")
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 899            8.3              1.02         0.02             3.4      0.084
# 45             4.6              0.52         0.15             2.1      0.054
# 652           15.9              0.36         0.65             7.5      0.096
# 142            5.2              0.34         0.00             1.8      0.050
# 821            4.9              0.42         0.00             2.1      0.048
# 588            5.0              0.42         0.24             2.0      0.060
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 899                  6.0                  11.0  0.99892  3.48       0.49
# 45                   8.0                  65.0  0.99340  3.90       0.56
# 652                 22.0                  71.0  0.99760  2.98       0.84
# 142                 27.0                  63.0  0.99160  3.68       0.79
# ...

# %%
dframe.groupby("quality").apply
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
from io import StringIO

# %%
data ="""Sample  Animal   Intelligence
1   Dog   Dumb
2 Dog Dumb
3   Cat Smart
4 Cat    Smart
5 Dog Smart
6 Cat Smart"""

# %%
dframe =pd.read_table(StringIO(data),sep="\s+")

# %%
dframe
# Out:
#    Sample Animal Intelligence
# 0       1    Dog         Dumb
# 1       2    Dog         Dumb
# 2       3    Cat        Smart
# 3       4    Cat        Smart
# 4       5    Dog        Smart
# 5       6    Cat        Smart

# %%
pd.crosstab(dframe.Animal,dframe.Intelligence)
# Out:
# Intelligence  Dumb  Smart
# Animal
# Cat              0      3
# Dog              2      1

# %%
pd.crosstab(dframe.Animal,dframe.Intelligence,margins=True)
# Out:
# Intelligence  Dumb  Smart  All
# Animal
# Cat              0      3    3
# Dog              2      1    3
# All              2      4    6
