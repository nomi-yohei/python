# %%
import pandas as pd
from pandas import Series

# %%
obj =Series([3,6,9,12])

# %%
obj
# Out:
# 0     3
# 1     6
# 2     9
# 3    12
# dtype: int64

# %%
obj.values
# Out:
# array([ 3,  6,  9, 12])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
ww2 =Series([87000000,43000000,30000000,21000000,40000000],index=["USER","GERMANY","CHINA","USA","JAPAN"])

# %%
ww2
# Out:
# USER       87000000
# GERMANY    43000000
# CHINA      30000000
# USA        21000000
# JAPAN      40000000
# dtype: int64

# %%
ww2["USA"]
# Out:
# 21000000

# %%
ww2[ww2>40000000]
# Out:
# USER       87000000
# GERMANY    43000000
# dtype: int64

# %%
ww2>40000000
# Out:
# USER        True
# GERMANY     True
# CHINA      False
# USA        False
# JAPAN      False
# dtype: bool

# %%
"USA" in ww2
# Out:
# True

# %%
ww2_dict=ww2.to_dict()
#辞書型

# %%
ww2_dic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-b4983babc3df> in <module>
# ----> 1 ww2_dic
#
# NameError: name 'ww2_dic' is not defined

# %%
ww2_dict
# Out:
# {'USER': 87000000,
#  'GERMANY': 43000000,
#  'CHINA': 30000000,
#  'USA': 21000000,
#  'JAPAN': 40000000}

# %%
ww23=Series(ww2_dict)

# %%
ww23
# Out:
# USER       87000000
# GERMANY    43000000
# CHINA      30000000
# USA        21000000
# JAPAN      40000000
# dtype: int64

# %%
countries =["GERMANY","CHINA","USA","JAPAN","USER","Coria"]

# %%
obj2 = Series(ww2_dict,index =countries)

# %%
obj2
# Out:
# GERMANY    43000000.0
# CHINA      30000000.0
# USA        21000000.0
# JAPAN      40000000.0
# USER       87000000.0
# Coria             NaN
# dtype: float64

# %%
pd.isnull(obj2)
# Out:
# GERMANY    False
# CHINA      False
# USA        False
# JAPAN      False
# USER       False
# Coria       True
# dtype: bool

# %%
pd.notnull(obj2)
# Out:
# GERMANY     True
# CHINA       True
# USA         True
# JAPAN       True
# USER        True
# Coria      False
# dtype: bool

# %%
ww23
# Out:
# USER       87000000
# GERMANY    43000000
# CHINA      30000000
# USA        21000000
# JAPAN      40000000
# dtype: int64

# %%
obj2
# Out:
# GERMANY    43000000.0
# CHINA      30000000.0
# USA        21000000.0
# JAPAN      40000000.0
# USER       87000000.0
# Coria             NaN
# dtype: float64

# %%
obj2 +ww23
# Out:
# CHINA       60000000.0
# Coria              NaN
# GERMANY     86000000.0
# JAPAN       80000000.0
# USA         42000000.0
# USER       174000000.0
# dtype: float64

# %%
obj2.name="第二次世界大戦"

# %%
obj2
# Out:
# GERMANY    43000000.0
# CHINA      30000000.0
# USA        21000000.0
# JAPAN      40000000.0
# USER       87000000.0
# Coria             NaN
# Name: 第二次世界大戦, dtype: float64

# %%
obj2.index.name ="countries"

# %%
obj2.values ="死者数"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5304                 else:
# -> 5305                     object.__setattr__(self, name, value)
#    5306             except (AttributeError, TypeError):
#
# AttributeError: can't set attribute
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-548f9924f84e> in <module>
# ----> 1 obj2.values ="死者数"
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5313                         stacklevel=2,
#    5314                     )
# -> 5315                 object.__setattr__(self, name, value)
#    5316
#    5317     def _dir_additions(self):
#
# AttributeError: can't set attribute

# %%
#ここまでが、lecture14
#ここからしたがlecture15

# %%
import numpy as np
#numptyの導入
import pandas as pd
#pandasの導入
from pandas import Series ,DataFrame

# %%
nfl_frame
# Out:
#    1        Dallas Cowboys    914  520  388   6   .572  1960   NFC East
# 0  2     Green Bay Packers  1,368  756  574  38  0.567  1921  NFC North
# 1  3  New England Patriots    916  512  395   9  0.564  1960   AFC East
# 2  4         Chicago Bears  1,402  769  591  42  0.563  1920  NFC North
# 3  5      Baltimore Ravens    384  214  169   1  0.559  1996  AFC North

# %%
nfl_frame
# Out:
#    1        Dallas Cowboys    914  520  388   6   .572  1960   NFC East
# 0  2     Green Bay Packers  1,368  756  574  38  0.567  1921  NFC North
# 1  3  New England Patriots    916  512  395   9  0.564  1960   AFC East
# 2  4         Chicago Bears  1,402  769  591  42  0.563  1920  NFC North
# 3  5      Baltimore Ravens    384  214  169   1  0.559  1996  AFC North

# %%
nfl_frame.columns
# Out:
# Index(['1', 'Dallas Cowboys', '914', '520', '388', '6', '.572', '1960',
#        'NFC East'],
#       dtype='object')

# %%
#lec15
#lec16下
import numpy as np
#numptyの導入
import pandas as pd
#pandasの導入
from pandas import Series ,DataFrame

# %%
import numpy as np
#numptyの導入
import pandas as pd
#pandasの導入
from pandas import Series ,DataFrame

# %%
my_ser =Series([1,2,3,4],index=["A","B","C","D"])

# %%
my_ser
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
my_index =my_ser.index

# %%
my_index
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
my_index[0]
# Out:
# 'A'

# %%
my_index[:]
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
my_index[:1]
# Out:
# Index(['A'], dtype='object')

# %%
my_index[1:]
# Out:
# Index(['B', 'C', 'D'], dtype='object')

# %%
my_index[0]="Z"
#書き換えふかである
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-fb3d8260e717> in <module>
# ----> 1 my_index[0]="Z"
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    3908
#    3909     def __setitem__(self, key, value):
# -> 3910         raise TypeError("Index does not support mutable operations")
#    3911
#    3912     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
#lec16
#lec17下
import numpy as np
#numptyの導入
import pandas as pd
#pandasの導入
from pandas import Series ,DataFrame
from numpy.random import randn
#正規分布に従ったものを注質
#idnexの変更

# %%
ser =Series([1,2,3,4],index=["A","B","C","D"])

# %%
ser
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
ser2 =ser.reindex(["A","B","C","D","E","F"])

# %%
ser2
# Out:
# A    1.0
# B    2.0
# C    3.0
# D    4.0
# E    NaN
# F    NaN
# dtype: float64

# %%
ser2.reindex(["A","B","C","D","E","F","G"],fill_value=0)
# Out:
# A    1.0
# B    2.0
# C    3.0
# D    4.0
# E    NaN
# F    NaN
# G    0.0
# dtype: float64

# %%
ser3 =Series(["usa","japan","corea"],index=[0,4,9])

# %%
ser3
# Out:
# 0      usa
# 4    japan
# 9    corea
# dtype: object

# %%
ser3.reindex(range(15),method="ffill")
# Out:
# 0       usa
# 1       usa
# 2       usa
# 3       usa
# 4     japan
# 5     japan
# 6     japan
# 7     japan
# 8     japan
# 9     corea
# 10    corea
# 11    corea
# 12    corea
# 13    corea
# 14    corea
# dtype: object

# %%
dframe=DataFrame(randn(25).reshape((5,5)),index=["A","B","D","E","F"],columns=["col1","col2","col3","col4","col5"])

# %%
dframe
# Out:
#        col1      col2      col3      col4      col5
# A -0.703735 -0.340287 -0.176526 -0.368684  1.681997
# B  0.063633 -0.658540 -0.083193  0.920365 -2.168615
# D -0.579320  1.731149 -0.151112 -0.597669  1.126909
# E -0.190048  2.688319 -0.396596  0.016654  0.107819
# F  0.125427  1.634115 -0.269419 -1.568499 -1.698105

# %%
new_index=["A","B","C","D","E","F"]
dframe2 =dframe.reindex(new_index)

# %%
dframe2
# Out:
#        col1      col2      col3      col4      col5
# A -0.703735 -0.340287 -0.176526 -0.368684  1.681997
# B  0.063633 -0.658540 -0.083193  0.920365 -2.168615
# C       NaN       NaN       NaN       NaN       NaN
# D -0.579320  1.731149 -0.151112 -0.597669  1.126909
# E -0.190048  2.688319 -0.396596  0.016654  0.107819
# F  0.125427  1.634115 -0.269419 -1.568499 -1.698105

# %%
new_colums =["col1","col2","col3","col4","col5","col6"]

# %%
dframe2.reindex(columns=new_colums )
# Out:
#        col1      col2      col3      col4      col5  col6
# A -0.703735 -0.340287 -0.176526 -0.368684  1.681997   NaN
# B  0.063633 -0.658540 -0.083193  0.920365 -2.168615   NaN
# C       NaN       NaN       NaN       NaN       NaN   NaN
# D -0.579320  1.731149 -0.151112 -0.597669  1.126909   NaN
# E -0.190048  2.688319 -0.396596  0.016654  0.107819   NaN
# F  0.125427  1.634115 -0.269419 -1.568499 -1.698105   NaN

# %%
dframe
# Out:
#        col1      col2      col3      col4      col5
# A -0.703735 -0.340287 -0.176526 -0.368684  1.681997
# B  0.063633 -0.658540 -0.083193  0.920365 -2.168615
# D -0.579320  1.731149 -0.151112 -0.597669  1.126909
# E -0.190048  2.688319 -0.396596  0.016654  0.107819
# F  0.125427  1.634115 -0.269419 -1.568499 -1.698105

# %%
dframe2.ix[new_index ,new_colums]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-bf1624d145a4> in <module>
# ----> 1 dframe2.ix[new_index ,new_colums]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
#lec17
#lec18下
import numpy as np
#numptyの導入
import pandas as pd
#pandasの導入
from pandas import Series ,DataFrame
# from numpy.random import randn
# #正規分布に従ったものを注質
# #idnexの変更

# %%
ser1 =Series(np.arange(3) ,index =["A","B","C"])

# %%
ser1
# Out:
# A    0
# B    1
# C    2
# dtype: int64

# %%
ser1.drop("B")
# Out:
# A    0
# C    2
# dtype: int64

# %%
dframe=DataFrame(np.arange(9).reshape((3,3)),index=["D","E","F"],columns=["col3","col4","col5"])

# %%
dframe
# Out:
#    col3  col4  col5
# D     0     1     2
# E     3     4     5
# F     6     7     8

# %%
dframe.drop("D")
# Out:
#    col3  col4  col5
# E     3     4     5
# F     6     7     8

# %%
dframe.drop("col3",axis=1)
# Out:
#    col4  col5
# D     1     2
# E     4     5
# F     7     8

# %%
#lec18
#lec19下
import numpy as np
#numptyの導入
import pandas as pd
#pandasの導入
from pandas import Series ,DataFrame
# from numpy.random import randn
# #正規分布に従ったものを注質
# #idnexの変更

# %%
ser1 =Series(np.arange(3),index =["A","B","C"])

# %%
ser1=2*ser1

# %%
ser1
# Out:
# A    0
# B    2
# C    4
# dtype: int64

# %%
ser1[["A","B"]]
# Out:
# A    0
# B    2
# dtype: int64

# %%
ser1[ser1>3]
# Out:
# C    99
# dtype: int64

# %%
ser1[ser1>3] =99

# %%
dframe =DataFrame(np.arange(25).reshape((5,5)),index=["NY","WC","jaoan","koko","jyon"],columns=["col3","col4","col5","col1","col2"])
# dframe=DataFrame(np.arange(9).reshape((3,3)),index=["D","E","F"],columns=["col3","col4","col5"])

# %%
dframe
# Out:
#        col3  col4  col5  col1  col2
# NY        0     1     2     3     4
# WC        5     6     7     8     9
# jaoan    10    11    12    13    14
# koko     15    16    17    18    19
# jyon     20    21    22    23    24

# %%
dframe.ix["NY"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-145-07e56b51ed0d> in <module>
# ----> 1 dframe.ix["NY"]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
#lec19
#lec20下
import numpy as np
#numptyの導入
import pandas as pd
#pandasの導入
from pandas import Series ,DataFrame
# from numpy.random import randn
# #正規分布に従ったものを注質
# #idnexの変更

# %%
ser1 =Series(np.arange(3),index =["A","B","C"])

# %%
ser1
# Out:
# A    0
# B    1
# C    2
# dtype: int64

# %%
ser2 =Series([3,4,5,6],index =["A","B","C","D"])

# %% [raw]
# ser2

# %%
ser2
# Out:
# A    3
# B    4
# C    5
# D    6
# dtype: int64

# %%
ser1+ser2
# Out:
# A    3.0
# B    5.0
# C    7.0
# D    NaN
# dtype: float64

# %%
dframe1 =DataFrame(np.arange(4).reshape((2,2)),index =["NY","JP"],columns=list("AB"))

# %%
dframe2 =DataFrame(np.arange(9).reshape((3,3)),index =["NY","SF","JP"],columns=list("ADC"))

# %%
dframe1
dframe2
dframe1.add(dframe2,fill_value=0)
# Out:
#       A    B    C    D
# JP  8.0  3.0  8.0  7.0
# NY  0.0  1.0  2.0  1.0
# SF  3.0  NaN  5.0  4.0

# %%
dframe2
# Out:
#     A  D  C
# NY  0  1  2
# SF  3  4  5
# JP  6  7  8

# %%
#lec20
#lec21下
import numpy as np
#numptyの導入
import pandas as pd
#pandasの導入
from pandas import Series ,DataFrame
# from numpy.random import randn
# #正規分布に従ったものを注質
# #idnexの変更

# %%
ser1=Series(range(3),index=["C","A","B"])

# %%
ser1.sort_index()
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %%
from numpy.random import randn

# %%
ser2 =Series(randn(10))

# %%
ser2
# Out:
# 0    0.582167
# 1    0.228030
# 2   -0.296239
# 3    0.275278
# 4   -2.371973
# 5    0.181702
# 6    0.243648
# 7   -2.004963
# 8    0.339838
# 9    0.797831
# dtype: float64

# %%
ser2.rank()
#順番を知れる
# Out:
# 0     9.0
# 1     5.0
# 2     3.0
# 3     7.0
# 4     1.0
# 5     4.0
# 6     6.0
# 7     2.0
# 8     8.0
# 9    10.0
# dtype: float64

# %%
ser2.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-196-8c47a48ba946> in <module>
# ----> 1 ser2.sort()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'sort'

# %% [raw]
# ser2.order()

# %%
ser2
# Out:
# 0    0.582167
# 1    0.228030
# 2   -0.296239
# 3    0.275278
# 4   -2.371973
# 5    0.181702
# 6    0.243648
# 7   -2.004963
# 8    0.339838
# 9    0.797831
# dtype: float64

# %%
#lec２１
#lec22下
import numpy as np
#numptyの導入
import pandas as pd
#pandasの導入
from pandas import Series ,DataFrame
# from numpy.random import randn
# #正規分布に従ったものを注質
# #idnexの変更

# %%
arr =np.array([[1,2,np.nan],[np.nan,3,4,]])

# %%
arr
# Out:
# array([[ 1.,  2., nan],
#        [nan,  3.,  4.]])

# %%
dframe =DataFrame(arr,index=["A","B"],columns=["One","Two","Three"])

# %%
dframe
# Out:
#    One  Two  Three
# A  1.0  2.0    NaN
# B  NaN  3.0    4.0

# %%
dframe.sum()
# Out:
# One      1.0
# Two      5.0
# Three    4.0
# dtype: float64

# %%
dframe.sum(axis=1)
# Out:
# A    3.0
# B    7.0
# dtype: float64

# %%
dframe.min()
# Out:
# One      1.0
# Two      2.0
# Three    4.0
# dtype: float64

# %%
dframe.idxmin()
# Out:
# One      A
# Two      A
# Three    B
# dtype: object

# %%
dframe
# Out:
#    One  Two  Three
# A  1.0  2.0    NaN
# B  NaN  3.0    4.0

# %%
dframe.cumsum()
# Out:
#    One  Two  Three
# A  1.0  2.0    NaN
# B  NaN  5.0    4.0

# %%
dframe.describe()
#データの平均な網羅できる
# Out:
#        One       Two  Three
# count  1.0  2.000000    1.0
# mean   1.0  2.500000    4.0
# std    NaN  0.707107    NaN
# min    1.0  2.000000    4.0
# 25%    1.0  2.250000    4.0
# 50%    1.0  2.500000    4.0
# 75%    1.0  2.750000    4.0
# max    1.0  3.000000    4.0

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-e3359946ffe8> in <module>
#       1 import pandas as pd
# ----> 2 import pandas.io.data as pdweb
#
# ModuleNotFoundError: No module named 'pandas.io.data'

# %%
from pandas_datareader import DataReader

# %%
import pandas_datareader as pdr
import pandas_datareader as pdr
import datetime
prices = pdr.DataReader(['CVX','XOM','BP'],'iex', start=datetime.datetime(2013, 1, 1),end=datetime.datetime(2015, 1, 1))['close']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-8789d68c3f4d> in <module>
#       2 import pandas_datareader as pdr
#       3 import datetime
# ----> 4 prices = pdr.DataReader(['CVX','XOM','BP'],'iex', start=datetime.datetime(2013, 1, 1),end=datetime.datetime(2015, 1, 1))['close']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     386
#     387     elif data_source == "iex":
# --> 388         return IEXDailyReader(
#     389             symbols=name,
#     390             start=start,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas_datareader/iex/daily.py in __init__(self, symbols, start, end, retry_count, pause, session, chunksize, api_key)
#      61             api_key = os.getenv("IEX_API_KEY")
#      62         if not api_key or not isinstance(api_key, str):
# ---> 63             raise ValueError(
#      64                 "The IEX Cloud API key must be provided either "
#      65                 "through the api_key variable or through the "
#
# ValueError: The IEX Cloud API key must be provided either through the api_key variable or through the  environment variable IEX_API_KEY

# %%
prices =pdr.get_data_yahoo(["CVX","XOM","BP"],start=datetime.datetime(2018,1,1),end=datetime.datetime(2019,1,1))

# %%
# prices = pdr.get_data_yahoo(['CVX','XOM','BP'],

#                                             start=datetime.datetime(2018, 1, 1),

#                                             end=datetime.datetime(2019, 1, 1))['close']

# %%
rets =prices.pct_change()

# %%
rets.head()
# Out:
# Attributes Adj Close                         Close                      \
# Symbols          CVX       XOM        BP       CVX       XOM        BP
# Date
# 2018-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-03  0.007289  0.019640  0.011562  0.007289  0.019640  0.011562
# 2018-01-04 -0.003113  0.001384  0.003966 -0.003113  0.001384  0.003966
# 2018-01-05 -0.001639 -0.000807  0.001394 -0.001639 -0.000806  0.001394
# 2018-01-08  0.004926  0.004496 -0.000464  0.004926  0.004496 -0.000464
#
# Attributes      High                           Low                      \
# Symbols          CVX       XOM        BP       CVX       XOM        BP
# Date
# 2018-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-03  0.009394  0.020775  0.010841  0.010833  0.013866  0.013633
# 2018-01-04 -0.004576  0.002875  0.006528  0.002522  0.018981  0.012270
# 2018-01-05 -0.001948 -0.003898 -0.000463 -0.000943 -0.008330 -0.001865
# 2018-01-08  0.004137  0.003108 -0.000695  0.004170  0.010384  0.001168
#
# Attributes      Open                        Volume
# Symbols          CVX       XOM        BP       CVX       XOM        BP
# Date
# 2018-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-03  0.013921  0.015987  0.008797  0.031905  0.216962  0.130491
# 2018-01-04  0.003844  0.019140  0.013670 -0.207941 -0.221720  0.286141
# 2018-01-05  0.000156 -0.000461  0.000930 -0.088968  0.016993 -0.370866
# 2018-01-08 -0.000860 -0.000576 -0.001394  0.152034 -0.010907 -0.179441

# %%
# %matplotlib inline

# %%
prices.plot()

# %% [raw]
# rets.corr()

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(rets.corr())

# %%
rets.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-767973348587> in <module>
# ----> 1 rets.unique()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
#lec２2
#lec23下
import numpy as np
#numptyの導入
import pandas as pd
#pandasの導入
from pandas import Series ,DataFrame
from numpy import nan
# from numpy.random import randn
# #正規分布に従ったものを注質
# #idnexの変更

# %%
data =Series(["one","two",nan,"four"])

# %%
data
# Out:
# 0     one
# 1     two
# 2     NaN
# 3    four
# dtype: object

# %%
data.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
data.dropna()
# Out:
# 0     one
# 1     two
# 3    four
# dtype: object

# %%
dframe =DataFrame([[1,2,3],[nan,5,6],[7,nan,9],[nan,nan,nan]])

# %%
dframe
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  NaN  5.0  6.0
# 2  7.0  NaN  9.0
# 3  NaN  NaN  NaN

# %%
dframe.dropna()
# Out:
#      0    1    2
# 0  1.0  2.0  3.0

# %%
dframe.dropna(how="all")
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  NaN  5.0  6.0
# 2  7.0  NaN  9.0

# %%
dframe.dropna(how="all")
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  NaN  5.0  6.0
# 2  7.0  NaN  9.0

# %%
dframe2 =DataFrame([[1,2,3,nan],[2,nan,5,6],[nan,7,nan,9],[nan,nan,nan,nan]])

# %%
dframe2
# Out:
#      0    1    2    3
# 0  1.0  2.0  3.0  NaN
# 1  2.0  NaN  5.0  6.0
# 2  NaN  7.0  NaN  9.0
# 3  NaN  NaN  NaN  NaN

# %%
dframe2.dropna(thresh=2)
# Out:
#      0    1    2    3
# 0  1.0  2.0  3.0  NaN
# 1  2.0  NaN  5.0  6.0
# 2  NaN  7.0  NaN  9.0

# %%
#lec２3
#lec24下
import numpy as np
#numptyの導入
import pandas as pd
#pandasの導入
from pandas import Series ,DataFrame
from numpy import nan
from numpy.random import randn
# #正規分布に従ったものを注質
# #idnexの変更

# %%
ser =Series(np.random.randn(6),index=[[1,1,1,2,2,2],["a","b","c","a","b","c"]])

# %%
ser
# Out:
# 1  a   -0.152456
#    b    0.146800
#    c    1.028908
# 2  a    0.960155
#    b   -0.746982
#    c   -1.349134
# dtype: float64

# %%
ser.index
# Out:
# MultiIndex([(1, 'a'),
#             (1, 'b'),
#             (1, 'c'),
#             (2, 'a'),
#             (2, 'b'),
#             (2, 'c')],
#            )

# %%
ser[1]
# Out:
# a   -0.152456
# b    0.146800
# c    1.028908
# dtype: float64

# %%
ser[2]
# Out:
# a    0.960155
# b   -0.746982
# c   -1.349134
# dtype: float64

# %%
ser[:,"a"]
# Out:
# 1   -0.152456
# 2    0.960155
# dtype: float64

# %%
ser[:,"a"]
# Out:
# 1   -0.152456
# 2    0.960155
# dtype: float64

# %%
dframe =ser.unstack()
#逆のものができる

# %%
dframe
# Out:
#           a         b         c
# 1 -0.152456  0.146800  1.028908
# 2  0.960155 -0.746982 -1.349134

# %%
dframe =ser.unstack()
dframe.unstack()
#逆のものができる
# Out:
# a  1   -0.152456
#    2    0.960155
# b  1    0.146800
#    2   -0.746982
# c  1    1.028908
#    2   -1.349134
# dtype: float64

# %%
dframe.T.unstack()
# Out:
# 1  a   -0.152456
#    b    0.146800
#    c    1.028908
# 2  a    0.960155
#    b   -0.746982
#    c   -1.349134
# dtype: float64

# %%
dframe2 =DataFrame(np.random.randn(16),reshape((4,4)),index=[["a","a","b","b"]])
